# %%
from io import StringIO # python3; python2: BytesIO 
import boto3
import pandas as pd

# %% [markdown]
# ## Source: API World Bank

# %%
pip install world_bank_data --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import world_bank_data as wb
pd.set_option('display.max_rows', 10)

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# ..                              ...
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
#                                            sourceNote
# id
# 1   For the 70 percent of the world's poor who liv...
# 2   Aid effectiveness is the impact that aid has i...
# 3   Economic growth is central to economic develop...
# 4   Education is one of the most powerful instrume...
# 5   The world economy needs ever-increasing amount...
# ..                                                ...
# 17  Gender equality is a core development objectiv...
# 18
# 19  Climate change is expected to hit developing c...
# ...

# %%
pd.options.display.max_rows = 4000
wb.search_indicators('diabetes')
# Out:
#                                                                      name  \
# id
# HF.STA.BLSG.ZS          Blood sugar measured in last 5 years (% of pop...
# HF.STA.BLSG.ZS.Q1       Blood sugar measured in last 5 years (% of pop...
# HF.STA.BLSG.ZS.Q2       Blood sugar measured in last 5 years (% of pop...
# HF.STA.BLSG.ZS.Q3       Blood sugar measured in last 5 years (% of pop...
# HF.STA.BLSG.ZS.Q4       Blood sugar measured in last 5 years (% of pop...
# HF.STA.BLSG.ZS.Q5       Blood sugar measured in last 5 years (% of pop...
# HF.STA.DIAB.ZS          Treated for raised blood glucose or diabetes (...
# HF.STA.DIAB.ZS.Q1       Treated for raised blood glucose or diabetes (...
# HF.STA.DIAB.ZS.Q2       Treated for raised blood glucose or diabetes (...
# HF.STA.DIAB.ZS.Q3       Treated for raised blood glucose or diabetes (...
# HF.STA.DIAB.ZS.Q4       Treated for raised blood glucose or diabetes (...
# HF.STA.DIAB.ZS.Q5       Treated for raised blood glucose or diabetes (...
# ...

# %%
#Diabetes prevalence
df_diabetes= pd.DataFrame(wb.get_series('SH.STA.DIAB.ZS', mrv=1))

# %%
#We create in AWS a bucket called s3diabetes with the folder diabetes-data were we are going to store all .csv files

# %%
def upload_s3(df,i):
    s3 = boto3.client("s3", aws_access_key_id="ASIA5Q5EPHLQSVLT7IMK",aws_secret_access_key="MpIHDAq556rNwT3V2bKzX9rXntGOjkCtDemZ1jkl", aws_session_token='')
    csv_buf = StringIO()
    df.to_csv(csv_buf, header=True, index=False)
    csv_buf.seek(0)    
    s3.put_object(Bucket="s3diabetes", Body=csv_buf.getvalue(), Key='diabetes-data/'+i)


upload_s3(df_diabetes,"s3diabetesworldbank.csv")

# %% [markdown]
# ## Source: API Kaggle

# %%
#!pip install kaggle
#!pip install --upgrade --force-reinstall --no-deps kaggle

# %%
# !kaggle datasets list -s 'diabetes'
# Out:
# ref                                                                      title                                          size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------------------  ---------------------------------------------  ----  -------------------  -------------  ---------  ---------------
# datasets/mathchi/diabetes-data-set                                       Diabetes Dataset                                9KB  2020-08-05 21:27:01          19151        231  1.0
# datasets/uciml/pima-indians-diabetes-database                            Pima Indians Diabetes Database                  9KB  2016-10-06 18:31:56         274541       3045  0.88235295
# datasets/johndasilva/diabetes                                            diabetes                                       12KB  2018-04-25 19:17:46           8139         95  0.4117647
# ...

# %%
# !kaggle datasets download -d pritsheta/diabetes-dataset --force
# Out:
# ...
#   0%|          | 0.00/8.91k [00:00<?, ?B/s]
# 100%|##########| 8.91k/8.91k [00:00<?, ?B/s]

# %%
import zipfile
z= zipfile.ZipFile('diabetes-dataset.zip')
z.extractall()
df_kaggle = pd.read_csv('diabetes.csv')

# %%
def upload_s3(df,i):
    s3 = boto3.client("s3", aws_access_key_id="ASIA5Q5EPHLQSVLT7IMK",aws_secret_access_key="MpIHDAq556rNwT3V2bKzX9rXntGOjkCtDemZ1jkl", aws_session_token='')
    csv_buf = StringIO()
    df.to_csv(csv_buf, header=True, index=False)
    csv_buf.seek(0)    
    s3.put_object(Bucket="s3diabetes", Body=csv_buf.getvalue(), Key='diabetes-data/'+i)


upload_s3(df_kaggle,"s3diabeteskaggle.csv")
